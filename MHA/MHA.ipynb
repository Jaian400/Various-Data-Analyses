# %% [markdown]
# # Moving householders analyze

# %%
# imports
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("ACSDT1Y2023.B25128-2025-03-11T090810.csv")

# %% [markdown]
# ### Data info

# %%
data.info()
data.describe()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Label (Grouping)               45 non-null     object
#  1   United States Estimate         45 non-null     float64
#  2   United States Margin of Error  45 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB
#                       Label (Grouping)  United States Estimate  \
# 0                               Total:             131332360.0
# 1                      Owner occupied:              85685869.0
# 2          Householder 15 to 34 years:               9128548.0
# 3               Moved in 2021 or later               4060736.0
# 4                Moved in 2018 to 2020               3139105.0
#
#    United States Margin of Error
# 0                       130190.0
# 1                       259497.0
# 2                        82458.0
# 3                        48616.0
# 4                        35649.0

# %% [markdown]
# ### Data refactoring

# %%
data.columns = data.columns.str.replace(r'_', ' ', regex=True)

# %%
data['United States Estimate'] = data['United States Estimate'].str.replace(',', '').astype(float)

# %%
data['United States Margin of Error'] = data['United States Margin of Error'].str.replace('±', '').str.replace(',','').astype(float)

# %%
data
# Out:
#                           Label (Grouping) United States Estimate  \
# 0                                   Total:            131,332,360
# 1                          Owner occupied:             85,685,869
# 2              Householder 15 to 34 years:              9,128,548
# 3                   Moved in 2021 or later              4,060,736
# 4                    Moved in 2018 to 2020              3,139,105
# 5                    Moved in 2010 to 2017              1,598,743
# 6                    Moved in 2000 to 2009                202,317
# 7                    Moved in 1990 to 1999                118,540
# 8                 Moved in 1989 or earlier                  9,107
# 9              Householder 35 to 64 years:             47,914,491
# 10                  Moved in 2021 or later              6,984,184
# 11                   Moved in 2018 to 2020              8,442,662
# 12                   Moved in 2010 to 2017             14,061,116
# 13                   Moved in 2000 to 2009             11,225,753
# 14                   Moved in 1990 to 1999              5,340,683
# 15                Moved in 1989 or earlier              1,860,093
# 16          Householder 65 years and over:             28,642,830
# 17                  Moved in 2021 or later              1,863,454
# 18                   Moved in 2018 to 2020              2,327,447
# 19                   Moved in 2010 to 2017              4,517,370
# 20                   Moved in 2000 to 2009              5,593,697
# 21                   Moved in 1990 to 1999              5,385,279
# 22                Moved in 1989 or earlier              8,955,583
# 23                        Renter occupied:             45,646,491
# 24             Householder 15 to 34 years:             16,163,425
# 25                  Moved in 2021 or later             11,375,572
# 26                   Moved in 2018 to 2020              3,438,048
# 27                   Moved in 2010 to 2017              1,148,220
# 28                   Moved in 2000 to 2009                139,530
# 29                   Moved in 1990 to 1999                 58,837
# 30                Moved in 1989 or earlier                  3,218
# 31             Householder 35 to 64 years:             21,645,533
# 32                  Moved in 2021 or later              8,097,012
# 33                   Moved in 2018 to 2020              5,597,187
# 34                   Moved in 2010 to 2017              5,468,041
# 35                   Moved in 2000 to 2009              1,778,994
# 36                   Moved in 1990 to 1999                486,931
# 37                Moved in 1989 or earlier                217,368
# 38          Householder 65 years and over:              7,837,533
# 39                  Moved in 2021 or later              2,043,674
# 40                   Moved in 2018 to 2020              1,592,817
# 41                   Moved in 2010 to 2017              2,128,574
# 42                   Moved in 2000 to 2009              1,053,020
# 43                   Moved in 1990 to 1999                491,972
# 44                Moved in 1989 or earlier                527,476
#
#    United States Margin of Error
# 0                       ±130,190
# 1                       ±259,497
# 2                        ±82,458
# 3                        ±48,616
# 4                        ±35,649
# 5                        ±25,611
# 6                         ±8,518
# 7                         ±6,966
# 8                         ±1,645
# 9                       ±144,021
# 10                       ±47,858
# 11                       ±51,203
# 12                       ±71,819
# 13                       ±62,950
# 14                       ±39,719
# 15                       ±25,385
# 16                       ±77,062
# 17                       ±25,720
# 18                       ±23,238
# 19                       ±33,079
# 20                       ±36,662
# 21                       ±42,587
# 22                       ±45,749
# 23                      ±154,839
# 24                       ±59,107
# 25                       ±54,159
# 26                       ±37,637
# 27                       ±23,329
# 28                        ±8,313
# 29                        ±5,414
# 30                        ±1,023
# 31                      ±110,152
# 32                       ±79,403
# 33                       ±58,191
# 34                       ±39,903
# 35                       ±28,285
# 36                       ±12,641
# 37                        ±8,863
# 38                       ±50,635
# 39                       ±25,864
# 40                       ±21,394
# 41                       ±23,489
# 42                       ±19,285
# 43                       ±12,921
# 44                       ±11,911
