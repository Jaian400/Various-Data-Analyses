# %% [markdown]
# # Moving householders analyze

# %%
# imports
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

data = pd.read_csv("ACSDT1Y2023.B25128-2025-03-11T090810.csv")

# %% [markdown]
# ### Data info

# %%
data.info()
data.describe()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 46 entries, (nan, 'Total', 'Total') to ('\xa0\xa0\xa0\xa0Renter occupied', 'Total', 'Total')
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   United States Estimate         46 non-null     object
#  1   United States Margin of Error  46 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB
#                                                                                           United States Estimate  \
# Occupation category Category                           Label (Grouping)
# NaN                 Total                              Total                                         131332360.0
#     Owner occupied  Total                              Total                                          85685869.0
#                             Householder 15 to 34 years Total                                           9128548.0
#                                                                    Moved in 2021 or later              4060736.0
#                                                                    Moved in 2018 to 2020               3139105.0
#
#                                                                                           United States Margin of Error
# Occupation category Category                           Label (Grouping)
# NaN                 Total                              Total                                                   130190.0
#     Owner occupied  Total                              Total                                                   259497.0
#                             Householder 15 to 34 years Total                                                    82458.0
#                                                                    Moved in 2021 or later                       48616.0
#                                                                    Moved in 2018 to 2020                        35649.0

# %% [markdown]
# ### Data refactoring and cleaning

# %%
data.columns = data.columns.str.replace(r'!!', ' ', regex=True)

data['United States Estimate'] = data['United States Estimate'].str.replace(',', '').astype(float)

data['United States Margin of Error'] = data['United States Margin of Error'].str.replace('±', '').str.replace(',','').astype(float)

# %% [markdown]
# ### Now there is a strong need to identify the rows acting as category titles

# %%
category_mask = data['Label (Grouping)'].str.endswith(':')
# category_mask

# %%
# add a cattegory row to easily identify every row
data['Category'] = data['Label (Grouping)'].where(category_mask).ffill()
data['Category'] = data['Category'].str.replace(':', '', regex=False) #some cleaning

data.loc[category_mask, 'Label (Grouping)'] = 'Total'  # rename categories as Total for clarity

# %%
occ_cat_mask = data['Category'].str.contains('occupied', case=False, regex=False, na=False)
data['Occupation category'] = data['Category'].where(occ_cat_mask).ffill()
data.loc[occ_cat_mask, 'Category'] = 'Total'

# %%
data.set_index(['Occupation category', 'Category', 'Label (Grouping)'], inplace=True) # gamechanger !1!!@!@ (in appearance)
# inplace=True → modifies the DataFrame directly instead of returning a new one

# %%
# reset indexes
data.reset_index(inplace=True)

# %%
# data.index.levels
data.xs('Owner occupied', level=0)
# Out:
# FrozenList([['    Owner occupied', '    Renter occupied'], ['Total', '        Householder 15 to 34 years', '        Householder 35 to 64 years', '        Householder 65 years and over'], ['Total', '            Moved in 1989 or earlier', '            Moved in 1990 to 1999', '            Moved in 2000 to 2009', '            Moved in 2010 to 2017', '            Moved in 2018 to 2020', '            Moved in 2021 or later']])

# %%
data
# Out:
#                                                                                                United States Estimate  \
# Occupation category Category                              Label (Grouping)
# NaN                 Total                                 Total                                           131332360.0
#     Owner occupied  Total                                 Total                                            85685869.0
#                             Householder 15 to 34 years    Total                                             9128548.0
#                                                                       Moved in 2021 or later                4060736.0
#                                                                       Moved in 2018 to 2020                 3139105.0
#                                                                       Moved in 2010 to 2017                 1598743.0
#                                                                       Moved in 2000 to 2009                  202317.0
#                                                                       Moved in 1990 to 1999                  118540.0
#                                                                       Moved in 1989 or earlier                 9107.0
#                             Householder 35 to 64 years    Total                                            47914491.0
#                                                                       Moved in 2021 or later                6984184.0
#                                                                       Moved in 2018 to 2020                 8442662.0
#                                                                       Moved in 2010 to 2017                14061116.0
#                                                                       Moved in 2000 to 2009                11225753.0
#                                                                       Moved in 1990 to 1999                 5340683.0
#                                                                       Moved in 1989 or earlier              1860093.0
#                             Householder 65 years and over Total                                            28642830.0
#                                                                       Moved in 2021 or later                1863454.0
#                                                                       Moved in 2018 to 2020                 2327447.0
#                                                                       Moved in 2010 to 2017                 4517370.0
#                                                                       Moved in 2000 to 2009                 5593697.0
#                                                                       Moved in 1990 to 1999                 5385279.0
#                                                                       Moved in 1989 or earlier              8955583.0
#     Renter occupied Total                                 Total                                            45646491.0
#                             Householder 15 to 34 years    Total                                            16163425.0
#                                                                       Moved in 2021 or later               11375572.0
#                                                                       Moved in 2018 to 2020                 3438048.0
#                                                                       Moved in 2010 to 2017                 1148220.0
#                                                                       Moved in 2000 to 2009                  139530.0
#                                                                       Moved in 1990 to 1999                   58837.0
#                                                                       Moved in 1989 or earlier                 3218.0
#                             Householder 35 to 64 years    Total                                            21645533.0
#                                                                       Moved in 2021 or later                8097012.0
#                                                                       Moved in 2018 to 2020                 5597187.0
#                                                                       Moved in 2010 to 2017                 5468041.0
#                                                                       Moved in 2000 to 2009                 1778994.0
#                                                                       Moved in 1990 to 1999                  486931.0
#                                                                       Moved in 1989 or earlier               217368.0
#                             Householder 65 years and over Total                                             7837533.0
#                                                                       Moved in 2021 or later                2043674.0
#                                                                       Moved in 2018 to 2020                 1592817.0
#                                                                       Moved in 2010 to 2017                 2128574.0
#                                                                       Moved in 2000 to 2009                 1053020.0
#                                                                       Moved in 1990 to 1999                  491972.0
#                                                                       Moved in 1989 or earlier               527476.0
#                     Total                                 Total                                                 Total
#
#                                                                                                United States Margin of Error
# Occupation category Category                              Label (Grouping)
# NaN                 Total                                 Total                                                     130190.0
#     Owner occupied  Total                                 Total                                                     259497.0
#                             Householder 15 to 34 years    Total                                                      82458.0
#                                                                       Moved in 2021 or later                         48616.0
#                                                                       Moved in 2018 to 2020                          35649.0
#                                                                       Moved in 2010 to 2017                          25611.0
#                                                                       Moved in 2000 to 2009                           8518.0
#                                                                       Moved in 1990 to 1999                           6966.0
#                                                                       Moved in 1989 or earlier                        1645.0
#                             Householder 35 to 64 years    Total                                                     144021.0
#                                                                       Moved in 2021 or later                         47858.0
#                                                                       Moved in 2018 to 2020                          51203.0
#                                                                       Moved in 2010 to 2017                          71819.0
#                                                                       Moved in 2000 to 2009                          62950.0
#                                                                       Moved in 1990 to 1999                          39719.0
#                                                                       Moved in 1989 or earlier                       25385.0
#                             Householder 65 years and over Total                                                      77062.0
#                                                                       Moved in 2021 or later                         25720.0
#                                                                       Moved in 2018 to 2020                          23238.0
#                                                                       Moved in 2010 to 2017                          33079.0
#                                                                       Moved in 2000 to 2009                          36662.0
#                                                                       Moved in 1990 to 1999                          42587.0
#                                                                       Moved in 1989 or earlier                       45749.0
#     Renter occupied Total                                 Total                                                     154839.0
#                             Householder 15 to 34 years    Total                                                      59107.0
#                                                                       Moved in 2021 or later                         54159.0
#                                                                       Moved in 2018 to 2020                          37637.0
#                                                                       Moved in 2010 to 2017                          23329.0
#                                                                       Moved in 2000 to 2009                           8313.0
#                                                                       Moved in 1990 to 1999                           5414.0
#                                                                       Moved in 1989 or earlier                        1023.0
#                             Householder 35 to 64 years    Total                                                     110152.0
#                                                                       Moved in 2021 or later                         79403.0
#                                                                       Moved in 2018 to 2020                          58191.0
#                                                                       Moved in 2010 to 2017                          39903.0
#                                                                       Moved in 2000 to 2009                          28285.0
#                                                                       Moved in 1990 to 1999                          12641.0
#                                                                       Moved in 1989 or earlier                        8863.0
#                             Householder 65 years and over Total                                                      50635.0
#                                                                       Moved in 2021 or later                         25864.0
#                                                                       Moved in 2018 to 2020                          21394.0
#                                                                       Moved in 2010 to 2017                          23489.0
#                                                                       Moved in 2000 to 2009                          19285.0
#                                                                       Moved in 1990 to 1999                          12921.0
#                                                                       Moved in 1989 or earlier                       11911.0
#                     Total                                 Total                                                        Total
